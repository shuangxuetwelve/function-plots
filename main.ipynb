# %%
# Third-party imports
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Hyperbolic Tangent (双曲正切函数)

# %%
x = np.arange(start=-5, stop=5, step=0.1)

y = np.tanh(x)

plt.plot(x, y)
plt.grid()

plt.show()
